# %%
class Human:

  #コンストラクタを定義する
  def __init__(self,name,age):
    self.name = name
    self.age = age

  #check_adultメソッドを定義する
  def check_adult(self):
    if self.age >= 20:
        print(f"{self.name}{self.age} 大人")
    else:
        print(f"{self.name}{self.age} 大人ではない")

#複数のHumanインスタンスを生成してリストに追加
humans = [
    Human("侍太郎",36),
    Human("侍花子",19),
    Human("侍次郎",22)
  ]

#リストの要素分だけcheck_adultメソッドを呼び出す
for human in humans:
    human.check_adult()
# Out:
# 侍太郎36 大人
# 侍花子19 大人ではない
# 侍次郎22 大人
